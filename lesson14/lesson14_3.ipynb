# %% [markdown]
# Python 的 list comprehension（串列綜合運算、列表推導式）是一種簡潔且有效率的語法，用來從一個現有序列（如 list、tuple、range 等）快速產生新的 list。它的主要目的是讓程式碼更為精簡、易讀，並且在某些情況下能提升運算效能。
#
# 基本語法
# list comprehension 的基本結構如下：
#
# python
# [expression for item in iterable if condition]
# expression：對 item 進行處理的運算式，結果會成為新 list 的元素。
#
# for item in iterable：從可疊代物件（iterable）中逐一取出元素。
#
# if condition（可選）：篩選條件，只有符合條件的元素才會被處理並放入新 list。
#
# 範例說明
# 範例一：產生 1 到 10 的平方數 list
#
# python
# squares = [x ** 2 for x in range(1, 11)]
# print(squares)
# # 輸出: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# 範例二：只取偶數的平方數
#
# python
# even_squares = [x ** 2 for x in range(1, 11) if x % 2 == 0]
# print(even_squares)
# # 輸出: [4, 16, 36, 64, 100]
# 範例三：組合兩個 list，只取相異元素
#
# python
# result = [(x, y) for x in [1, 2, 3] for y in [3, 1, 4] if x != y]
# print(result)
# # 輸出: [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]
# 這種寫法等同於多層 for 迴圈，但更為簡潔。
#
# 優點
# 程式碼簡潔：用一行就能完成原本需要多行 for 迴圈才能達成的功能。
#
# 可讀性高：語法直觀，容易理解。
#
# 效能較佳：在某些情況下，list comprehension 的執行速度比傳統 for 迴圈快，因為它是用更低階的 bytecode 來建立 list。
#
# 適用範圍
# 除了 list，Python 還支援 dict comprehension 和 set comprehension，語法類似，只是用花括號包圍。
#
# 總結
# list comprehension 是 Python 中非常實用的語法，能大幅簡化資料處理和 list 生成的程式碼，提升開發效率與可讀性。

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager
import random

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

#list comprehension
#days = [day for day in range(1,31)]

#list建構式
days = list(range(1,31))

july = [round(random.uniform(28.5, 35.2),ndigits=1) for _ in range(1,31)]
august = [round(random.uniform(28.5, 35.2),ndigits=1) for _ in range(1,31)]

# %%
# 1.製作figure
figure = plt.figure(figsize=(8, 12),dpi=240,facecolor='#cccccc') #寬8 高5 
# 2.在1.的figure上製作一個axes
axes1 = figure.add_subplot(2,1,1) #2行1列的第1個子圖

axes1.plot(days, july,marker='o',color='r',linestyle='-.',label='7月')
axes1.set_xticks(days)
axes1.legend()
axes1.grid(axis='y')
axes1.set_title('7月溫度') #圖標題
axes1.set_xlabel=("日期")
axes1.set_ylabel=("攝氏")

axes2 = figure.add_subplot(2,1,2) #2行1列的第2個子圖
axes2.scatter(days, august,marker='x',color='g',label='8月')
axes2.set_xticks(days)
axes2.legend()
axes2.grid(axis='y')
axes2.set_title('8月溫度')
axes2.set_xlabel=("日期")
axes2.set_ylabel=("攝氏")
plt.tight_layout() #自動調整圖
plt.show()
plt.close()
