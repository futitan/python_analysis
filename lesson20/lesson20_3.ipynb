# %% [markdown]
# https://www.perplexity.ai/search/cea283c5-8750-41ff-8811-20ec42b77262

# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
import numpy as np
import pandas as pd

url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?page=0&size=1000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')

records = response.json()
#records
allRecords = pd.DataFrame(records,columns=['sna','tot','mday','sbi','sarea','ar','bemp'])
allRecords1 = allRecords.rename(columns= {'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還','mday':'時間'})
allRecords1
# Out:
# 沒有發生問題
#                          站名  數量              時間  可借   區域  \
# 0           YouBike2.0_下庄市場  20  20250615150803  14  八里區
# 1         YouBike2.0_八里行政中心  20  20250615160702   3  八里區
# 2     YouBike2.0_八里中庄市場綜合大樓  28  20250615160102   2  八里區
# 3           YouBike2.0_大崁國小  20  20250615153704   3  八里區
# 4          YouBike2.0_龍形停車場  40  20250615160702   3  八里區
# ..                      ...  ..             ...  ..  ...
# 995        YouBike2.0_深坑松柏街  34  20250615111504   2  深坑區
# 996  YouBike2.0_深坑區公所(深坑老街)  30  20250615160202   9  深坑區
# 997       YouBike2.0_東南科技大學  18  20250615155517   0  深坑區
# 998        YouBike2.0_深坑雲鄉路  12  20250615160102   2  深坑區
# 999      YouBike2.0_埔新街61巷口  15  20250615142703   5  深坑區
#
#                        地址  可還
# 0               舊城路21號(前)   6
# 1    十三行路(靠中山路二段路口西南側人行道)  17
# 2    中山路一段268巷2號(對面汽車停車場)  26
# 3                忠八街2號(前)  17
# 4        龍米路一段318號(對面停車場)  37
# ..                    ...  ..
# 995              松柏街24號西側  32
# 996              文化街45號西側  21
# 997           北深路三段170號南側  17
# 998               雲鄉路1號北側  10
# 999            埔新街73號(對側)  10
#
# [1000 rows x 7 columns]

# %%
allRecords1['站名']=allRecords1['站名'].apply(lambda name:name[11:])

# %%
allRecords1
# Out:
#               站名  數量              時間  可借   區域                    地址  可還
# 0           下庄市場  20  20250615150803  14  八里區             舊城路21號(前)   6
# 1         八里行政中心  20  20250615160702   3  八里區  十三行路(靠中山路二段路口西南側人行道)  17
# 2     八里中庄市場綜合大樓  28  20250615160102   2  八里區  中山路一段268巷2號(對面汽車停車場)  26
# 3           大崁國小  20  20250615153704   3  八里區              忠八街2號(前)  17
# 4          龍形停車場  40  20250615160702   3  八里區      龍米路一段318號(對面停車場)  37
# ..           ...  ..             ...  ..  ...                   ...  ..
# 995        深坑松柏街  34  20250615111504   2  深坑區              松柏街24號西側  32
# 996  深坑區公所(深坑老街)  30  20250615160202   9  深坑區              文化街45號西側  21
# 997       東南科技大學  18  20250615155517   0  深坑區           北深路三段170號南側  17
# 998        深坑雲鄉路  12  20250615160102   2  深坑區               雲鄉路1號北側  10
# 999      埔新街61巷口  15  20250615142703   5  深坑區            埔新街73號(對側)  10
#
# [1000 rows x 7 columns]

# %%
allRecords1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      1000 non-null   object
#  1   數量      1000 non-null   object
#  2   時間      1000 non-null   object
#  3   可借      1000 non-null   object
#  4   區域      1000 non-null   object
#  5   地址      1000 non-null   object
#  6   可還      1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %%
allRecords1['時間']=pd.to_datetime(allRecords1['時間'])
allRecords1
# Out:
#               站名  數量                  時間  可借   區域                    地址  可還
# 0           下庄市場  20 2025-06-15 15:08:03  14  八里區             舊城路21號(前)   6
# 1         八里行政中心  20 2025-06-15 16:07:02   3  八里區  十三行路(靠中山路二段路口西南側人行道)  17
# 2     八里中庄市場綜合大樓  28 2025-06-15 16:01:02   2  八里區  中山路一段268巷2號(對面汽車停車場)  26
# 3           大崁國小  20 2025-06-15 15:37:04   3  八里區              忠八街2號(前)  17
# 4          龍形停車場  40 2025-06-15 16:07:02   3  八里區      龍米路一段318號(對面停車場)  37
# ..           ...  ..                 ...  ..  ...                   ...  ..
# 995        深坑松柏街  34 2025-06-15 11:15:04   2  深坑區              松柏街24號西側  32
# 996  深坑區公所(深坑老街)  30 2025-06-15 16:02:02   9  深坑區              文化街45號西側  21
# 997       東南科技大學  18 2025-06-15 15:55:17   0  深坑區           北深路三段170號南側  17
# 998        深坑雲鄉路  12 2025-06-15 16:01:02   2  深坑區               雲鄉路1號北側  10
# 999      埔新街61巷口  15 2025-06-15 14:27:03   5  深坑區            埔新街73號(對側)  10
#
# [1000 rows x 7 columns]

# %%
allRecords1[['數量','可借','可還']] = allRecords1[['數量','可借','可還']].astype(int)

# %%
allRecords1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      1000 non-null   object
#  1   數量      1000 non-null   int64
#  2   時間      1000 non-null   datetime64[ns]
#  3   可借      1000 non-null   int64
#  4   區域      1000 non-null   object
#  5   地址      1000 non-null   object
#  6   可還      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
grouped=allRecords1.groupby('區域')
agg_df = grouped[['數量','可借','可還']].agg([("加總","sum"),("平均","mean"),("中間數","median"),("最多","max"),("最少","min")])

# %%
agg_df
# Out:
#        數量                             可借                            可還  \
#        加總         平均   中間數  最多  最少    加總         平均   中間數  最多 最少    加總
# 區域
# 三峽區  1540  22.318841  20.0  63  10   671   9.724638   8.0  25  0   868
# 三芝區   170  21.250000  16.0  48  14    45   5.625000   5.5  11  2   125
# 三重區  3774  30.435484  28.5  95  11  1453  11.717742  10.0  92  0  2246
# 中和區  3483  33.490385  30.0  99  10  1374  13.211538  10.0  83  0  2071
# 五股區   667  22.233333  20.0  48  13   230   7.666667   7.0  18  0   431
# 八里區   533  21.320000  20.0  46  13   118   4.720000   3.0  15  1   412
# 土城區  2828  32.136364  30.0  94   9   784   8.909091   6.5  47  0  1962
# 坪林區    65  21.666667  22.0  23  20     7   2.333333   1.0   6  0    58
# 平溪區   174  34.800000  30.0  55  20    29   5.800000   7.0   8  1   145
# 板橋區  7366  36.107843  34.0  99   9  2235  10.955882   7.0  83  0  4903
# 林口區  2233  26.583333  23.5  99  10   864  10.285714   8.0  54  0  1355
# 永和區  1548  28.145455  23.0  79  10   467   8.490909   5.0  35  0  1043
# 汐止區  2397  32.391892  28.5  99   9  1030  13.918919   9.0  78  0  1332
# 泰山區   668  26.720000  22.0  45  12   221   8.840000   7.0  25  0   444
# 淡水區  2073  25.912500  21.0  98  10   699   8.737500   6.0  36  0  1353
# 深坑區   109  21.800000  18.0  34  12    18   3.600000   2.0   9  0    90
# 烏來區    28  28.000000  28.0  28  28     6   6.000000   6.0   6  6    22
# 石碇區    52  17.333333  15.0  23  14    19   6.333333   8.0  10  1    33
# 石門區   102  34.000000  26.0  56  20    19   6.333333   6.0   7  6    83
# 貢寮區    60  20.000000  20.0  20  20    21   7.000000   4.0  16  1    39
# 金山區   163  23.285714  24.0  30  15    39   5.571429   6.0   9  3   124
#
#
#             平均   中間數  最多  最少
# 區域
# 三峽區  12.579710  11.0  41   3
# 三芝區  15.625000  14.0  43   3
# 三重區  18.112903  15.0  70   1
# 中和區  19.913462  17.5  55   2
# 五股區  14.366667  12.0  47   6
# 八里區  16.480000  13.0  43   6
# 土城區  22.295455  20.0  59   3
# 坪林區  19.333333  19.0  22  17
# 平溪區  29.000000  29.0  50  12
# 板橋區  24.034314  21.0  90   0
# 林口區  16.130952  12.5  97   3
# 永和區  18.963636  16.0  61   0
# 汐止區  18.000000  15.5  69   0
# 泰山區  17.760000  15.0  40   3
# 淡水區  16.912500  14.0  77   0
# 深坑區  18.000000  17.0  32  10
# 烏來區  22.000000  22.0  22  22
# 石碇區  11.000000  13.0  14   6
# 石門區  27.666667  20.0  50  13
# 貢寮區  13.000000  16.0  19   4
# 金山區  17.714286  15.0  27   9

# %%
agg_df.columns.names = ["租借","統計"]
s1 = agg_df.stack(level=['租借','統計'],future_stack=True)
s1
# Out:
# 區域   租借  統計
# 三峽區  數量  加總     1540.000000
#          平均       22.318841
#          中間數      20.000000
#          最多       63.000000
#          最少       10.000000
#                    ...
# 金山區  可還  加總      124.000000
#          平均       17.714286
#          中間數      15.000000
#          最多       27.000000
#          最少        9.000000
# Length: 315, dtype: float64

# %%
s1.unstack(level="統計")
# Out:
# 統計          加總         平均   中間數    最多    最少
# 區域  租借
# 三峽區 數量  1540.0  22.318841  20.0  63.0  10.0
#     可借   671.0   9.724638   8.0  25.0   0.0
#     可還   868.0  12.579710  11.0  41.0   3.0
# 三芝區 數量   170.0  21.250000  16.0  48.0  14.0
#     可借    45.0   5.625000   5.5  11.0   2.0
# ...        ...        ...   ...   ...   ...
# 貢寮區 可借    21.0   7.000000   4.0  16.0   1.0
#     可還    39.0  13.000000  16.0  19.0   4.0
# 金山區 數量   163.0  23.285714  24.0  30.0  15.0
#     可借    39.0   5.571429   6.0   9.0   3.0
#     可還   124.0  17.714286  15.0  27.0   9.0
#
# [63 rows x 5 columns]
