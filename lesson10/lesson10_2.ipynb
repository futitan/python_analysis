# %% [markdown]
# # python 如何讀取students.csv
#
# 你可以使用 Python 內建的 csv 模組來讀取 students.csv，以下是簡單的範例：
# ----------------
# import csv
#
# with open('students.csv', newline='', encoding='utf-8') as csvfile:
#     reader = csv.DictReader(csvfile)  # 使用 DictReader 讀取成字典格式
#     for row in reader:
#         print(row)  # 每一列會是字典，鍵是欄位名稱
# 說明：
#
# open() 中指定 encoding='utf-8' 避免中文亂碼。
# csv.DictReader 會自動把 CSV 第一列當作欄位名稱，並將每列轉成字典。
# 你也可以用 csv.reader 讀成串列形式，但 DictReader 更適合有欄位標題的 CSV。
# 執行後，每一列會輸出類似：
#
# {'姓名': '錢欣潔', '國文': '100', '英文': '77', '數學': '59'}
# {'姓名': '許芳如', '國文': '98', '英文': '74', '數學': '99'}
# {'姓名': '陳怡伶', '國文': '54', '英文': '67', '數學': '79'}
# 這是讀取 CSV 檔案並取得每筆資料的標準作法[1][2][4][5]。

# %%
import csv
from csv import DictReader

with open('students.csv',encoding='utf-8',newline='') as csv_file:
    reader:DictReader = csv.DictReader(csv_file)
    students = list(reader)
    
students
# Out:
# [{'姓名': '陳家維', '國文': '90', '英文': '62', '數學': '80'},
#  {'姓名': '彭偉妃', '國文': '64', '英文': '82', '數學': '85'},
#  {'姓名': '姜琬婷', '國文': '70', '英文': '84', '數學': '100'},
#  {'姓名': '林珍旺', '國文': '53', '英文': '74', '數學': '55'},
#  {'姓名': '張凱妮', '國文': '92', '英文': '68', '數學': '71'},
#  {'姓名': '林昱芳', '國文': '83', '英文': '99', '數學': '62'},
#  {'姓名': '林俊翔', '國文': '70', '英文': '53', '數學': '92'},
#  {'姓名': '劉林中', '國文': '86', '英文': '68', '數學': '85'},
#  {'姓名': '陳信念', '國文': '58', '英文': '76', '數學': '75'},
#  {'姓名': '陳得映', '國文': '66', '英文': '86', '數學': '65'},
#  {'姓名': '陳冠霞', '國文': '94', '英文': '56', '數學': '52'},
#  {'姓名': '林希啟', '國文': '72', '英文': '55', '數學': '71'},
#  {'姓名': '王梅劭', '國文': '99', '英文': '55', '數學': '92'},
#  {'姓名': '盧文啟', '國文': '73', '英文': '75', '數學': '53'},
#  {'姓名': '葉祖雄', '國文': '51', '英文': '94', '數學': '59'},
#  {'姓名': '王筱婷', '國文': '97', '英文': '65', '數學': '87'},
#  {'姓名': '王怡珊', '國文': '100', '英文': '97', '數學': '85'},
#  {'姓名': '趙家豪', '國文': '56', '英文': '72', '數學': '73'},
#  {'姓名': '溫重意', '國文': '52', '英文': '84', '數學': '60'},
#  {'姓名': '邱亭君', '國文': '100', '英文': '50', '數學': '81'},
#  {'姓名': '翁羽威', '國文': '83', '英文': '72', '數學': '95'},
#  {'姓名': '蒙淑惠', '國文': '54', '英文': '56', '數學': '80'},
#  {'姓名': '林義皓', '國文': '55', '英文': '72', '數學': '78'},
#  {'姓名': '黃嘉琪', '國文': '71', '英文': '85', '數學': '58'},
#  {'姓名': '林志喜', '國文': '96', '英文': '52', '數學': '69'},
#  {'姓名': '張俊傑', '國文': '75', '英文': '90', '數學': '79'},
#  {'姓名': '楊少亮', '國文': '96', '英文': '55', '數學': '88'},
#  {'姓名': '林思賢', '國文': '96', '英文': '54', '數學': '95'},
#  {'姓名': '洪阿惠', '國文': '67', '英文': '72', '數學': '93'},
#  {'姓名': '趙偉銘', '國文': '54', '英文': '92', '數學': '97'},
#  {'姓名': '黃奎紹', '國文': '100', '英文': '64', '數學': '55'},
#  {'姓名': '陳美惠', '國文': '94', '英文': '58', '數學': '85'},
#  {'姓名': '吳志宣', '國文': '86', '英文': '62', '數學': '86'},
#  {'姓名': '陳向愛', '國文': '92', '英文': '54', '數學': '51'},
#  {'姓名': '林向鈺', '國文': '83', '英文': '81', '數學': '67'},
#  {'姓名': '許芳如', '國文': '71', '英文': '76', '數學': '89'},
#  {'姓名': '高俊男', '國文': '99', '英文': '58', '數學': '57'},
#  {'姓名': '胡芳瑜', '國文': '83', '英文': '51', '數學': '76'},
#  {'姓名': '林玉佩', '國文': '75', '英文': '57', '數學': '89'},
#  {'姓名': '蔡孟泉', '國文': '55', '英文': '78', '數學': '68'},
#  {'姓名': '郭淑真', '國文': '67', '英文': '58', '數學': '73'},
#  {'姓名': '李慈啟', '國文': '83', '英文': '91', '數學': '67'},
#  {'姓名': '楊又源', '國文': '86', '英文': '97', '數學': '92'},
#  {'姓名': '張韋成', '國文': '66', '英文': '66', '數學': '70'},
#  {'姓名': '王坤安', '國文': '57', '英文': '72', '數學': '65'},
#  {'姓名': '元延辛', '國文': '78', '英文': '65', '數學': '58'},
#  {'姓名': '唐翊修', '國文': '70', '英文': '71', '數學': '71'},
#  {'姓名': '李美洋', '國文': '97', '英文': '62', '數學': '61'},
#  {'姓名': '楊韋廷', '國文': '51', '英文': '62', '數學': '54'},
#  {'姓名': '黃善迪', '國文': '85', '英文': '72', '數學': '64'}]
